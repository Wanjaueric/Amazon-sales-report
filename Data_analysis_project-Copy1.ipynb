# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"D:\Datasets\AmazonSalesData.csv")
df
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          100 non-null    object
#  1   Country         100 non-null    object
#  2   Item Type       100 non-null    object
#  3   Sales Channel   100 non-null    object
#  4   Order Priority  100 non-null    object
#  5   Order Date      100 non-null    object
#  6   Order ID        100 non-null    int64
#  7   Ship Date       100 non-null    object
#  8   Units Sold      100 non-null    int64
#  9   Unit Price      100 non-null    float64
#  10  Unit Cost       100 non-null    float64
#  11  Total Revenue   100 non-null    float64
#  12  Total Cost      100 non-null    float64
#  13  Total Profit    100 non-null    float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 11.1+ KB

# %%
df.head(3)
# Out:
#                               Region  Country        Item Type Sales Channel  \
# 0              Australia and Oceania   Tuvalu        Baby Food       Offline
# 1  Central America and the Caribbean  Grenada           Cereal        Online
# 2                             Europe   Russia  Office Supplies       Offline
#
#   Order Priority Order Date   Order ID  Ship Date  Units Sold  Unit Price  \
# 0              H  5/28/2010  669165933  6/27/2010        9925      255.28
# 1              C  8/22/2012  963881480  9/15/2012        2804      205.70
# 2              L   5/2/2014  341417157   5/8/2014        1779      651.21
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 0     159.42     2533654.00  1582243.50     951410.50
# 1     117.11      576782.80   328376.44     248406.36
# 2     524.96     1158502.59   933903.84     224598.75

# %%
df.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
df.shape
# Out:
# (100, 14)

# %%
df.size
# Out:
# 1400

# %%
df.describe()
# Out:
#            Order ID   Units Sold  Unit Price   Unit Cost  Total Revenue  \
# count  1.000000e+02   100.000000  100.000000  100.000000   1.000000e+02
# mean   5.550204e+08  5128.710000  276.761300  191.048000   1.373488e+06
# std    2.606153e+08  2794.484562  235.592241  188.208181   1.460029e+06
# min    1.146066e+08   124.000000    9.330000    6.920000   4.870260e+03
# 25%    3.389225e+08  2836.250000   81.730000   35.840000   2.687212e+05
# 50%    5.577086e+08  5382.500000  179.880000  107.275000   7.523144e+05
# 75%    7.907551e+08  7369.000000  437.200000  263.330000   2.212045e+06
# max    9.940222e+08  9925.000000  668.270000  524.960000   5.997055e+06
#
#          Total Cost  Total Profit
# count  1.000000e+02  1.000000e+02
# mean   9.318057e+05  4.416820e+05
# std    1.083938e+06  4.385379e+05
# min    3.612240e+03  1.258020e+03
# 25%    1.688680e+05  1.214436e+05
# 50%    3.635664e+05  2.907680e+05
# 75%    1.613870e+06  6.358288e+05
# max    4.509794e+06  1.719922e+06

# %%
df.isnull().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
df.dtypes
# Out:
# Region             object
# Country            object
# Item Type          object
# Sales Channel      object
# Order Priority     object
# Order Date         object
# Order ID            int64
# Ship Date          object
# Units Sold          int64
# Unit Price        float64
# Unit Cost         float64
# Total Revenue     float64
# Total Cost        float64
# Total Profit      float64
# dtype: object

# %%
df = df.astype({'Order Date': 'datetime64[ns]', 'Ship Date': 'datetime64[ns]'})

# %%
df.dtypes
# Out:
# Region                    object
# Country                   object
# Item Type                 object
# Sales Channel             object
# Order Priority            object
# Order Date        datetime64[ns]
# Order ID                   int64
# Ship Date         datetime64[ns]
# Units Sold                 int64
# Unit Price               float64
# Unit Cost                float64
# Total Revenue            float64
# Total Cost               float64
# Total Profit             float64
# dtype: object

# %%
df = df.fillna(df.mean(numeric_only = True))
df
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %% [markdown]
# # Data Analysis

# %% [markdown]
# # 1.	Which regions have the highest total sales revenue?

# %%
Highest_total_revenue = df.groupby(df['Region'])['Total Revenue'].sum()
Highest_total_revenue.idxmax()
# Out:
# 'Sub-Saharan Africa'

# %%
group_data = df.groupby(df['Region'])['Total Revenue'].sum()

sns.set_style( 'darkgrid' )
plt.figure(figsize = (15,10))
sns.lineplot(data = group_data, linestyle = '--', marker = 'o', markersize = 10, markerfacecolor = 'red', markeredgecolor = 'black')

plt.title("Highest Total Sales Revenue by Region", color = 'Blue', fontsize = 20)
plt.xlabel('Regions', color = 'Red', fontsize = 20)
plt.ylabel('Total Revenue', color = 'Red', fontsize = 20)
plt.show()

# %% [markdown]
# # 2.	What is the average unit price and unit cost for each item type?

# %%
Avg_unit_price = df.groupby(df['Item Type'])['Unit Price'].mean()
Avg_unit_cost = df.groupby(df['Item Type'])['Unit Cost'].mean()

Avg_price_cost = pd.DataFrame({'Average unit price':Avg_unit_price,
                             'Average unit cost': Avg_unit_cost})
Avg_price_cost
# Out:
#                  Average unit price  Average unit cost
# Item Type
# Baby Food                    255.28             159.42
# Beverages                     47.45              31.79
# Cereal                       205.70             117.11
# Clothes                      109.28              35.84
# Cosmetics                    437.20             263.33
# Fruits                         9.33               6.92
# Household                    668.27             502.54
# Meat                         421.89             364.69
# Office Supplies              651.21             524.96
# Personal Care                 81.73              56.67
# Snacks                       152.58              97.44
# Vegetables                   154.06              90.93

# %% [markdown]
# # 3.Which country has the highest total profit?

# %%
Total_profit_by_country = df.groupby(df['Country'])['Total Profit'].sum()
Highest_Total_profit_by_country  = Total_profit_by_country.idxmax()
print('The Country with the highest profit is', Highest_Total_profit_by_country)
# Out:
# The Country with the highest profit is Djibouti

# %%
group_data = df.groupby(df['Country'])['Total Profit'].sum()

sns.set_style( 'darkgrid' )
plt.figure(figsize = (15,10))
sns.barplot(x = group_data.index, y = group_data)

plt.title('Country with Highest total profit', fontsize = 20, color = 'Blue')
plt.xlabel('Country', fontsize = 20, color = 'Red')
plt.xticks(rotation = 90)
plt.ylabel('Total Profit', fontsize = 20, color = 'Red')
plt.show()

# %% [markdown]
# # 4.	How does the sales channel affect the order priority distribution?

# %%
sales_channel = df.groupby(df['Sales Channel'])['Order Priority'].value_counts()
sales_channel
# Out:
# Sales Channel  Order Priority
# Offline        H                 17
#                C                 13
#                L                 12
#                M                  8
# Online         L                 15
#                H                 13
#                M                 13
#                C                  9
# Name: count, dtype: int64

# %%
sales_channel_order_priority_distribution= df.groupby(df['Sales Channel'])['Order Priority'].count()

# reset the indexto convert the grouped data into a Dataframe
sales_channel_order_priority_distribution = sales_channel.reset_index(name = 'Count')

# set the style
#plt.style.use('fivethirtyeight')
sns.set_style('darkgrid')
plt.figure(figsize = (15,10))
sns.barplot(data =sales_channel_order_priority_distribution , x = 'Sales Channel', y = 'Count', hue = 'Order Priority')

#add labels
plt.title('Sales channel order priority distribution')
plt.xlabel(' Sales Channel')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # 5.	What is the average order processing time (duration between order and ship dates) for each sales channel?

# %%
df['Processing Time'] = df['Ship Date'] - df['Order Date']
Avg_Processing_Time = df.groupby(df['Sales Channel'])['Processing Time'].mean()
Avg_Processing_Time
# Out:
# Sales Channel
# Offline   23 days 04:48:00
# Online    23 days 12:28:48
# Name: Processing Time, dtype: timedelta64[ns]

# %% [markdown]
# # 6.Which items types have the highest and lowest total sales?

# %%
group_item_type = df.groupby(df['Item Type'])['Total Revenue'].sum()
highest_sales_revenue_item_type = group_item_type.idxmax()
lowest_sales_revenue_item_type = group_item_type.idxmin()

print('Highest sales Revenue by Item Type', highest_sales_revenue_item_type)
print('Lowest sales Revenue by Item Type',lowest_sales_revenue_item_type)
# Out:
# Highest sales Revenue by Item Type Cosmetics
# Lowest sales Revenue by Item Type Fruits

# %%
plt.figure(figsize =(10,5))
plt.style.use('seaborn-v0_8-darkgrid')

# highest max value
sns.scatterplot(x = group_item_type.index, y = group_item_type, s = 200)
max_index = group_item_type.idxmax()
plt.scatter(x = max_index, y = group_item_type[max_index], s = 200, color = 'Green', edgecolor = 'Black')

#lowest max value
min_index = group_item_type.idxmin()
plt.scatter(x = min_index, y = group_item_type[min_index], s = 200, color = 'Red', edgecolor = 'Black')

plt.title('Scatter plot showing highest and lowest sales per Item Type')
plt.xticks(rotation = 60)

plt.show()

# %% [markdown]
# # 7.	How does the order priority vary across different regions?

# %%
Regions_by_order_priority = df.groupby(df['Region'])['Order Priority'].value_counts().reset_index(name = 'Order_priority_Count')
Regions_by_order_priority
# Out:
#                                Region Order Priority  Order_priority_Count
# 0                                Asia              L                     4
# 1                                Asia              H                     3
# 2                                Asia              C                     2
# 3                                Asia              M                     2
# 4               Australia and Oceania              H                     5
# 5               Australia and Oceania              C                     4
# 6               Australia and Oceania              L                     1
# 7               Australia and Oceania              M                     1
# 8   Central America and the Caribbean              C                     2
# 9   Central America and the Caribbean              H                     2
# 10  Central America and the Caribbean              L                     2
# ...

# %%
Regions_by_order_priority = df.groupby(df['Region'])['Order Priority'].value_counts().reset_index(name = 'Order Priority Count')

plt.figure(figsize = (15,10))

sns.barplot(data = Regions_by_order_priority, x= 'Region', y = 'Order Priority Count' , hue = 'Order Priority')

plt.title('Order of priority per Regions')
plt.xticks(rotation = 90)
plt.yticks(np.arange(1,15,1))

plt.show()

# %% [markdown]
# # 8.	What is the correlation between unit price and total profit?

# %%
correlation_unit_price_total_profit = df['Unit Price'].corr(df['Total Profit'])
print('Correlation between Unit price and Total Profit:' ,correlation_unit_price_total_profit)
# Out:
# Correlation between Unit price and Total Profit: 0.5573652488121267

# %%
plt.figure(figsize = (10,5))
plt.scatter(x = correlation_unit_price_total_profit, y = correlation_unit_price_total_profit, s = 200, color = 'Red')

plt.title('Correlation_Unit_price_Total_profit')
plt.xticks(np.arange(-1, 2, 0.5))
plt.yticks(np.arange(-1, 2, 0.5))

plt.show()

# %% [markdown]
# # 9.	Are there any seasonal trends or patterns in the sales data?

# %%
month_names= {1: 'JAN',
              2: 'FEB',
              3: 'MAR',
              4: 'APR',
              5: 'MAY',
              6: 'JUN',
              7: 'JUL',
              8: 'AUG',
              9: 'SEPT',
             10: 'OCT',
             11: 'NOV',
             12: 'DEC'}
monthly_sales = df.groupby(df['Order Date'].dt.month)['Total Revenue'].sum()
monthly_sales.index= monthly_sales.index.map(month_names)

monthly_sales
# Out:
# Order Date
# JAN     10482467.12
# FEB     24740517.77
# MAR      2274823.87
# APR     16187186.33
# MAY     13215739.99
# JUN      5230325.77
# JUL     15669518.50
# AUG      1128164.91
# SEPT     5314762.56
# OCT     15287576.61
# NOV     20568222.76
# DEC      7249462.12
# Name: Total Revenue, dtype: float64

# %%
sns.barplot(x= monthly_sales.index, y= monthly_sales)
plt.title('Month Wise Total Revenue')
plt.xlabel('Month')
plt.ylabel('Total Revenue')
plt.show()

# %% [markdown]
# # 10.	How does the number of units sold vary across different countries?

# %%
Diff_countries_by_unit_sold= df.groupby(df['Country'])['Units Sold'].sum().reset_index(name= 'Unit Sold')
pd.set_option('display.max_rows',None)
Diff_countries_by_unit_sold
# Out:
#                              Country  Unit Sold
# 0                            Albania       2269
# 1                             Angola       4187
# 2                          Australia      12995
# 3                            Austria       2847
# 4                         Azerbaijan       9255
# 5                         Bangladesh       8263
# 6                             Belize       5498
# 7                             Brunei       6708
# 8                           Bulgaria       5660
# 9                       Burkina Faso       8082
# 10                          Cameroon      10948
# 11                        Cape Verde       4168
# 12                           Comoros        962
# 13                        Costa Rica       6409
# 14                     Cote d'Ivoire       3482
# 15  Democratic Republic of the Congo       5741
# 16                          Djibouti      23198
# 17                        East Timor       5908
# 18    Federated States of Micronesia       9379
# ...
